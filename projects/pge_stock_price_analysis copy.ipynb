# %% [markdown]
# # Supervised Learning - Course Final Project
#
# ## PG&E Stock Analysis.
#
# ### Objectives
# - Assess if the impact of the fires on the stock price has been fully reversed.
# - Is the stock is still underpriced?
#
# ### Peer Utility companies selected to comparative analysis
# - Edison International (EIX)
# - Sempra Energy (SRE)
# - NextEra Energy, Inc. (NEE)
# - Duke Energy Corporation (DUK)
# - Exelon Corporation (EXC)
# - American Electric Power Company, Inc. (AEP)
# - Dominion Energy, Inc. (D)
# - FirstEnergy Corp. (FE)
# - PPL Corporation (PPL)
# - Entergy Corporation (ETR)
# - Xcel Energy Inc. (XEL)
# - Consolidated Edison, Inc. (ED)
# - Public Service Enterprise Group (PSEG)
# - National Grid plc (NGG)
# - CMS Energy Corporation (CMS)
# - DTE Energy Company (DTE)
# - Alliant Energy Corporation (LNT)
# - CenterPoint Energy, Inc. (CNP)
# - AES Corporation (AES)
# - Avangrid, Inc. (AGR)
# - Eversource Energy (ES)
#
#
# ### Materials and Methods
#
# #### Step 1: Data Collection
# Historical Stock Prices: Collect historical stock prices of PG&E and its peers.
#
#
# Gather PG&E’s financial statements (balance sheets, income statements, cash flow statements) for multiple years.
# Access this data through the company’s investor relations website, SEC filings, or financial databases like Bloomberg or Reuters.
#
# Market Data:
# Collect market indices data (e.g., S&P 500, utilities index) for benchmarking purposes.
# Get data on interest rates, inflation rates, and other macroeconomic indicators.
#
#
# News and Sentiment Analysis:
#
# Extract news articles, press releases, and social media sentiment related to PG&E.
# Use natural language processing (NLP) to analyze sentiment and potential impacts on stock prices.
#
#
# #### Step 2: Preprocessing Data
# Clean and Normalize Data:
#
# Handle missing values, outliers, and data inconsistencies.
# Normalize the data for consistency, especially financial ratios.
# Feature Engineering:
#
# Create relevant financial ratios (e.g., P/E ratio, debt-to-equity ratio, EBITDA).
# Generate technical indicators (e.g., moving averages, RSI, MACD).
# Develop sentiment scores from news and social media data.
#
# #### Step 3: Exploratory Data Analysis (EDA)
# Visualize Data:
#
# Plot stock price trends and compare with peers and market indices.
# Visualize financial ratios and their trends over time.
# Correlation Analysis:
#
# Analyze correlations between PG&E’s stock price and financial ratios, technical indicators, and sentiment scores.
#
# #### Step 4: Model Building
# Supervised Learning Models:
#
# Regression Models: Use linear regression, Lasso, Ridge, and decision tree regression to predict stock prices based on financial and technical indicators.
# Classification Models: Implement models like logistic regression, SVM, and random forests to classify if the stock is undervalued (buy) or overvalued (sell).
# Time Series Models:
#
# ARIMA: Autoregressive Integrated Moving Average for forecasting future stock prices.
# LSTM: Long Short-Term Memory neural networks for capturing long-term dependencies in stock price movements.
# Ensemble Methods:
#
# Use ensemble techniques like Random Forest, Gradient Boosting, or XGBoost for improved prediction accuracy.
#
# #### Step 5: Model Evaluation
# Backtesting:
#
# Backtest your models using historical data to evaluate their performance.
# Measure metrics such as Mean Absolute Error (MAE), Mean Squared Error (MSE), and accuracy for classification models.
# Cross-Validation:
#
# Perform cross-validation to ensure your models are not overfitting and generalize well to unseen data.
#
# #### Step 6: Interpretation and Decision-Making
# Feature Importance:
#
# Analyze feature importance to understand which factors are driving the stock price predictions.
# Use SHAP (SHapley Additive exPlanations) values for detailed interpretation.
# Investment Decision:
#
# Based on model predictions and feature analysis, assess if PG&E is currently underpriced.
# Combine machine learning insights with traditional financial analysis and industry knowledge.
#
# #### xStep 7: Continuous Monitoring and Improvement
# Update Models:
#
# Continuously update your models with new data to maintain their accuracy.
# Implement a pipeline for regular data ingestion, model retraining, and evaluation.
# Monitor Market Conditions:
#
# Keep an eye on market conditions, regulatory changes, and news events that could impact PG&E’s stock price.
# By following these steps, you can build a comprehensive machine-learning framework to assess if PG&E is underpriced after the fires it was accused of causing. This approach will help you make informed investment decisions based on data-driven insights.
#
# ### The DataSet
